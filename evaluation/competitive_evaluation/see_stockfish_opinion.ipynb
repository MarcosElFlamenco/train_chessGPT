# %%
import see_stockfish_opinion as g

json_file = "../outputs/stockfish_opinion.json"
game_index = 9
#check games 477 and 478
g.plot_game_evaluation(json_file,game_index)
# Out:
# Game 10 Result: Unknown

# %%
import importlib
importlib.reload(g)

g.analyze_and_plot_game_statistics(json_file)
# Out:
# White Wins:
# Number of Wins: 0
# Outliers (Checkmate): 0
# N/A
# N/A
# N/A
#
# Black Wins:
# Number of Wins: 0
# Outliers (Checkmate): 0
# N/A
# N/A
# N/A
#
# Draws:
# Number of Draws: 0
# Outliers (Checkmate): 0
# N/A
# N/A
# N/A

# %%
import importlib
importlib.reload(g)

g.analyze_and_plot_game_statistics(json_file)
# Out:
# White Wins:
# Number of Wins: 0
# Outliers (Checkmate): 0
# N/A
# N/A
# N/A
#
# Black Wins:
# Number of Wins: 0
# Outliers (Checkmate): 0
# N/A
# N/A
# N/A
#
# Draws:
# Number of Draws: 0
# Outliers (Checkmate): 0
# N/A
# N/A
# N/A

# %%
import importlib
importlib.reload(g)
pgn_file = "eval_datasets/kasparov2128games.pgn"
g.analyze_best_scores(json_file,pgn_file)
# Out:
# Identified a blunder in game 478 at move 71
# Game 479:
#
# Moves:
# give it a minute we're not quite there yet
#
# Best Black Scores in White Wins:
# Number of Games: 842
# Max Score: 0.37 pawns
# Min Score: -10.28 pawns
# Avg Score: -0.31 pawns
#
# Best White Scores in Black Wins:
# Number of Games: 401
# Max Score: 7.78 pawns
# Min Score: 0.04 pawns
# Avg Score: 1.03 pawns

# %%
import importlib 
importlib.reload(g)
pgn_string1 = "1.e4 c5 2.Nf3 d6 3.d4 cxd4 4.Nxd4 Nf6 5.Nc3 a6 6.Be3 e6 7.f3 Nbd7 8.g4 h6 \
9.h4 Ne5 10.Rg1 Qb6 11.Qc1 d5 12.Be2 dxe4 13.Nxe4 Nxe4 14.fxe4 Be7 15.Rh1 Bd7 \
16.c3 Qc7 17.Bf2 b5 18.Qc2 Nc4 19.Bxc4 Qxc4 20.b3 Qc7 21.O-O-O O-O 22.Kb1 a5 \
23.g5 h5 24.Rhg1 a4 25.b4 Rac8 26.Rd3 g6 27.Bg3 Qb7 28.Qe2 Rc4 29.Be5 Rfc8 \
30.Qe3 Bc6 31.Re1 a3 32.Qf2 Be8 33.Nb3 Qc6 34.Na5 Rxb4+ 35.Ka1 Qc5 36.cxb4 Qc1 37."
pgn_string = "1.Nf3 d6 2.d4 Bg4 3.e4 Nf6 4.Nc3 e6 5.Be2 Be7 6.O-O O-O 7.Be3 Nbd7 8.Nd2 Bxe2 \
9.Qxe2 c5 10.dxc5 Nxc5 11.Bxc5 dxc5 12.Nc4 Qc7 13.a4 Rad8 14.e5 Nd5 15.Ne4 Nb6 \
16.Ncd6 f5 17.Nc3 a6 18.a5 Nd5 19.Nc4 Nf4 20.Qf3 Rd4 21.b4 Ng6 22.Rfe1 Rf4 \
23.Qe3 Qc6 24.f3 Bg5 25.Qe2 Rd4 26.g3 Rfd8 27.Rad1 Be7 28.Qg2 f4 29.Qe2 h5 \
30.Rxd4 Rxd4 31.Ne4 fxg3 32.hxg3 h4 33.c3 Rd5 34.f4 hxg3 35.Qg4 Nh4 36.Nf6+ Bxf6 \
37.exf6 Nf5 38.Ne5 Qd6 39.Qh5 Rxe5 40.Rxe5 Qd2 41.Qe2 Qxc3 42.Rxe6 Qa1+ 43.Kg2 gxf6"

stck_path = "../../stockfish-ubuntu-x86-64-avx2/stockfish/stockfish1" 
g.evaluate_and_play_moves(pgn_string,stck_path,max_moves=20)
# Out:
# Initial Evaluation: 999.93 pawns (Time: 0.105974 seconds)
#
# Move 1: e6e8
# New Evaluation: 999.94 pawns (Time: 0.101080 seconds)
#
# Move 2: g8f7
# New Evaluation: 999.94 pawns (Time: 0.101172 seconds)
#
# Move 3: e2h5
# New Evaluation: 999.95 pawns (Time: 0.100953 seconds)
#
# Move 4: f7g7
# New Evaluation: 999.95 pawns (Time: 0.101213 seconds)
#
# Move 5: h5g4
# New Evaluation: 999.96 pawns (Time: 0.100897 seconds)
#
# Move 6: g7h7
# New Evaluation: 999.96 pawns (Time: 0.099093 seconds)
#
# Move 7: g4f5
# New Evaluation: 999.97 pawns (Time: 0.042406 seconds)
#
# Move 8: h7g7
# New Evaluation: 999.97 pawns (Time: 0.027143 seconds)
#
# Move 9: f5d7
# New Evaluation: 999.98 pawns (Time: 0.022846 seconds)
#
# Move 10: g7g6
# New Evaluation: 999.98 pawns (Time: 0.019288 seconds)
#
# Move 11: e8g8
# New Evaluation: 999.99 pawns (Time: 0.016834 seconds)
#
# Move 12: g6h6
# New Evaluation: 999.99 pawns (Time: 0.009810 seconds)
#
# Move 13: d7h3
# ...

# %%
import importlib
importlib.reload(g)

pgn_file = "eval_datasets/kasparov2128games.pgn"
g.print_nth_game(pgn_file,478)
# Out:
# Game 479:
#
# Moves:
# [Event "London m"]
# [Site "London"]
# [Date "1987.??.??"]
# [Round "6"]
# [White "Short, Nigel D"]
# [Black "Kasparov, Gary"]
# [Result "1-0"]
# [WhiteElo "2615"]
# [BlackElo "2735"]
# [ECO "B80"]
#
# 1. e4 c5 2. Nf3 d6 3. d4 cxd4 4. Nxd4 Nf6 5. Nc3 a6 6. Be3 e6 7. f3 Nbd7 8. g4 h6 9. h4 Ne5 10. Rg1 Qb6 11. Qc1 d5 12. Be2 dxe4 13. Nxe4 Nxe4 14. fxe4 Be7 15. Rh1 Bd7 16. c3 Qc7 17. Bf2 b5 18. Qc2 Nc4 19. Bxc4 Qxc4 20. b3 Qc7 21. O-O-O O-O 22. Kb1 a5 23. g5 h5 24. Rhg1 a4 25. b4 Rac8 26. Rd3 g6 27. Bg3 Qb7 28. Qe2 Rc4 29. Be5 Rfc8 30. Qe3 Bc6 31. Re1 a3 32. Qf2 Be8 33. Nb3 Qc6 34. Na5 Rxb4+ 35. Ka1 Qc5 36. cxb4 Qxb4 37. Qd2 Rc2 38. Qxb4 Bxb4 39. Rd8 f6 40. Rf1 fxe5 41. Rxe8+ Kg7 42. Nb3 Bc3+ 43. Kb1 Rb2+ 44. Kc1 Rxb3 45. Kc2 1-0
# give it a minute we're not quite there yet
